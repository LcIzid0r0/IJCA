# %% [markdown]
# <a href="https://colab.research.google.com/github/LcIzid0r0/IJCA/blob/main/DESAFIO_FINAL_1001_HISTORICO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTAÇÃO BIBLIOTECA

# %%
import pandas as pd
# !pip install pyarrow
import io
# Out:
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (18.1.0)

# %% [markdown]
# IMPORTAÇÃO ARQUIVO PARQUETS

# %%
file_path = '/content/drive/MyDrive/export_sd_chamados_historico_part-00000-tid-4316804262685302617-660de38f-1493-4f46-b3a8-4cc819403a2f-30-1-c000.snappy.parquet'
df = pd.read_parquet(file_path)

# %% [markdown]
# PADRONIZAÇÃO null para Não Informada

# %%
df.description = df.description.replace({'null': 'Não Informada'})

# %% [markdown]
# PADRONIZAÇÃO PARA FORMATO CORRETO

# %%
df['time.value'] = df['time.value'] .astype(int)
df['time.value'] = pd.to_datetime(df['time.value'], unit='ms', utc=True).dt.tz_convert('America/Sao_Paulo')

# %% [markdown]
# DROP DE COLUNAS

# %%
df.drop('time.display_value', axis=1, inplace=True)

# %%
df.drop('by.first_name', axis=1, inplace=True)

# %%
df.drop('by.photo_url', axis=1, inplace=True)

# %%
df.drop('by.last_name', axis=1, inplace=True)

# %%
df.set_index('id', inplace=True)

# %%
df.head()
#df.info()
#f.isnull().sum()
# Out:
#                                                           description  \
# id
# 110633000051865114                                      Não Informada
# 110633000051877490                        Uma conversa foi adicionada
# 110633000051877492                                      Não Informada
# 110633000051877496                                      Não Informada
# 110633000051877504   Motivo : Aguardando retorno do solicitante pa...
#
#                                                                  diff  \
# id
# 110633000051865114                                                 []
# 110633000051877490                                                 []
# 110633000051877492  [{'field': 'responded_time', 'previous_value':...
# 110633000051877496  [{'field': 'status', 'previous_value': {'in_pr...
# 110633000051877504  [{'field': 'REQUEST_TIMER_COMMENTS', 'previous...
#
#                           operation                        by.name  \
# id
# 110633000051865114              add  Dener Augusto Tiberto Martins
# 110633000051877490            reply                   Claudio imai
# 110633000051877492             edit                         System
# 110633000051877496             edit                   Claudio imai
# 110633000051877504  onhold_schedule                   Claudio imai
#
#                                  by.id                       time.value  \
# id
# 110633000051865114  110633000000228320 2024-05-09 17:41:05.627000-03:00
# 110633000051877490  110633000035153032 2024-05-10 15:50:30.240000-03:00
# 110633000051877492  110633000000006619 2024-05-10 15:50:30.240000-03:00
# 110633000051877496  110633000035153032 2024-05-10 15:50:30.885000-03:00
# 110633000051877504  110633000035153032 2024-05-10 15:50:30.882000-03:00
#
#                             id_chamado
# id
# 110633000051865114  110633000051865110
# 110633000051877490  110633000051865110
# 110633000051877492  110633000051865110
# 110633000051877496  110633000051865110
# 110633000051877504  110633000051865110

# %% [markdown]
# DADOS TRATADOS GOLD - DOWNLOAD

# %%
df.to_parquet('dados_historico.parquet', engine='pyarrow', compression='snappy')

# %%
from google.colab import files
files.download('dados_historico.parquet')
